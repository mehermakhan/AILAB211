# %%
print("hello")
# Out:
# hello

# %% [markdown]
# **coding**

# %% [markdown]
# # ⚓basic python **coding**\\\\\

# %% [markdown]
# numpy

# %%
import numpy as np

arr = np.array([1, 2, 3, 4])
print(arr + 2)
# Out:
# [3 4 5 6]

# %% [markdown]
# matplotlip

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3]
y = [2, 4, 6]

plt.plot(x, y)
plt.show()

# %% [markdown]
# sum max min

# %%
# Create a list with 10 integers
numbers = [5, 12, 7, 3, 18, 9, 21, 4, 6, 10]

# Find sum
total = sum(numbers)

# Find maximum
maximum = max(numbers)

# Find minimum
minimum = min(numbers)

# Display results
print("List:", numbers)
print("Sum:", total)
print("Maximum:", maximum)
print("Minimum:", minimum)
# Out:
# List: [5, 12, 7, 3, 18, 9, 21, 4, 6, 10]
# Sum: 95
# Maximum: 21
# Minimum: 3

# %% [markdown]
# add and remove **element**

# %%
# Create a list
numbers = [5, 12, 7, 3, 18, 9, 21, 4, 6, 10]

print("Original List:", numbers)

# 🔹 Add element (at end)
numbers.append(25)

# 🔹 Add element at specific position (index 2)
numbers.insert(2, 99)

print("After Adding:", numbers)

# 🔹 Remove element by value
numbers.remove(7)

# 🔹 Remove element by index
numbers.pop(3)

print("After Removing:", numbers)
# Out:
# Original List: [5, 12, 7, 3, 18, 9, 21, 4, 6, 10]
# After Adding: [5, 12, 99, 7, 3, 18, 9, 21, 4, 6, 10, 25]
# After Removing: [5, 12, 99, 18, 9, 21, 4, 6, 10, 25]

# %% [markdown]
# sort assendind and **descending**

# %%
# Create a list
numbers = [5, 12, 7, 3, 18, 9, 21, 4, 6, 10]

print("Original List:", numbers)

# 🔹 Sort in Ascending Order
numbers.sort()
print("Ascending Order:", numbers)

# 🔹 Sort in Descending Order
numbers.sort(reverse=True)
print("Descending Order:", numbers)
# Out:
# Original List: [5, 12, 7, 3, 18, 9, 21, 4, 6, 10]
# Ascending Order: [3, 4, 5, 6, 7, 9, 10, 12, 18, 21]
# Descending Order: [21, 18, 12, 10, 9, 7, 6, 5, 4, 3]

# %% [markdown]
# create a tuple

# %%
fruit = ["mango","orange","banana"] # Changed to a list
fruit.remove("mango")
print(fruit)
# Out:
# ['orange', 'banana']

# %% [markdown]
# create sets

# %%
set_a= {1,2,3,4}
print(set)
# Out:
# <class 'set'>

# %% [markdown]
# union and intersection

# %%
# Create two sets
set1 = {1, 2, 3, 4, 5}
set2 = {4, 5, 6, 7, 8}

print("Set 1:", set1)
print("Set 2:", set2)

# 🔹 Union (combine all elements, no duplicates)
union_set = set1.union(set2)

# 🔹 Intersection (common elements)
intersection_set = set1.intersection(set2)

print("Union:", union_set)
print("Intersection:", intersection_set)
# Out:
# Set 1: {1, 2, 3, 4, 5}
# Set 2: {4, 5, 6, 7, 8}
# Union: {1, 2, 3, 4, 5, 6, 7, 8}
# Intersection: {4, 5}

# %% [markdown]
# ```
# # dictonary
# ```

# %%
students={'mehr':100,'taqwa':20}
print(students)
# Out:
# {'mehr': 100, 'taqwa': 20}
