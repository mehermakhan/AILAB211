# %% [markdown]
# ![ucs 33.png](data:image/png;base64,...)

# %%
import heapq

def ucs(graph, start, goal):
    pq = []  # priority queue (cost, node, path)
    heapq.heappush(pq, (0, start, [start]))

    visited = set()

    while pq:
        cost, node, path = heapq.heappop(pq)

        if node == goal:
            return cost, path

        if node in visited:
            continue

        visited.add(node)

        for neighbor, weight in graph[node]:
            if neighbor not in visited:
                heapq.heappush(pq, (cost + weight, neighbor, path + [neighbor]))

    return float('inf'), []

# ---------------- GRAPH (from your image approx) ----------------
graph = {
    'A': [('C', 4)],
    'B': [('A', 1), ('E', 3), ('P', 2)],
    'C': [('E', 5)],
    'E': [('P', 1)],
    'P': [('S', 2)],
    'S': []
}

start = 'B'
goal = 'S'

cost, path = ucs(graph, start, goal)

print("Minimum Cost:", cost)
print("Path:", " -> ".join(path))
# Out:
# Minimum Cost: 4
# Path: B -> P -> S
